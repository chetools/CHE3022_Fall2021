# %% [markdown]
# <a href="https://colab.research.google.com/github/profteachkids/CHE3022_Fall2021/blob/main/FiniteDifferencing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from plotly.subplots import make_subplots
import plotly.io as pio
pio.templates.default='plotly_dark'

# %%
nx = 100
nt = 1000
r = 0.2

# %%
T = np.full(nx, 300.)
x=np.arange(nx)
T[0]=350.
T[-1]=400.

# %%
fig = make_subplots(rows=1,cols=1)
fig.add_scatter(x=x, y =T, mode='lines', name='Initial')
for i in range(1, 5):
    T[1:-1]=T[1:-1]+r*(T[2:]-2*T[1:-1]+T[:-2])
    fig.add_scatter(x=x, y=T, mode='lines', name=f'{i}')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="95ed98f3-1635-4638-98ba-f0a064986b03" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("95ed98f3-1635-4638-98ba-f0a064986b03")) {
#                     Plotly.newPlot(
#                         '95ed98f3-1635-4638-98ba-f0a064986b03',
# ...

# %%
# Out:
# array([350.    , 326.8096, 310.72  , 303.04  , 300.5728, 300.064 ,
#        300.0032, 300.    , 300.    , 300.    , 300.    , 300.    ,
#        300.    , 300.    , 300.    , 300.    , 300.    , 300.    ,
#        300.    , 300.    , 300.    , 300.    , 300.    , 300.    ,
#        300.    , 300.    , 300.    , 300.    , 300.    , 300.    ,
#        300.    , 300.    , 300.    , 300.    , 300.    , 300.    ,
#        300.    , 300.    , 300.    , 300.    , 300.    , 300.    ,
#        300.    , 300.    , 300.    , 300.    , 300.    , 300.    ,
#        300.    , 300.    , 300.    , 300.    , 300.    , 300.    ,
#        300.    , 300.    , 300.    , 300.    , 300.    , 300.    ,
#        300.    , 300.    , 300.    , 300.    , 300.    , 300.    ,
#        300.    , 300.    , 300.    , 300.    , 300.    , 300.    ,
#        300.    , 300.    , 300.    , 300.    , 300.    , 300.    ,
#        300.    , 300.    , 300.    , 300.    , 300.    , 300.    ,
# ...

# %%
T[-1]
# Out:
# 400
